# %%
import pandas as pd

df =pd.read_csv('./assignments/billboard.csv')
df
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
df = df.melt(id_vars=['year' ,'artist', 'track' ,'time' ,'date.entered'], var_name='week', value_name='rank')
df = df.dropna()
df = df.reset_index()
df
# Out:
#       index  year        artist                    track  time date.entered  \
# 0         0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1         1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2         2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08
# 3         3  2000  3 Doors Down                    Loser  4:24   2000-10-21
# 4         4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...   ...           ...                      ...   ...          ...
# 5302  19716  2000         Creed                   Higher  5:16   1999-09-11
# 5303  19833  2000      Lonestar                   Amazed  4:25   1999-06-05
# 5304  20033  2000         Creed                   Higher  5:16   1999-09-11
# 5305  20150  2000      Lonestar                   Amazed  4:25   1999-06-05
# 5306  20350  2000         Creed                   Higher  5:16   1999-09-11
#
#       week  rank
# 0      wk1  87.0
# 1      wk1  91.0
# ...

# %%
df[['c','week1']] = df['week'].str.split('k',expand=True)
df = df.drop(columns=['c','week'])
df.rename(columns={'week1':'week'},inplace=True)
df['week'] = df['week'].astype(int)
df
# Out:
#       index  year        artist                    track  time date.entered  \
# 0         0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1         1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2         2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08
# 3         3  2000  3 Doors Down                    Loser  4:24   2000-10-21
# 4         4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...   ...           ...                      ...   ...          ...
# 5302  19716  2000         Creed                   Higher  5:16   1999-09-11
# 5303  19833  2000      Lonestar                   Amazed  4:25   1999-06-05
# 5304  20033  2000         Creed                   Higher  5:16   1999-09-11
# 5305  20150  2000      Lonestar                   Amazed  4:25   1999-06-05
# 5306  20350  2000         Creed                   Higher  5:16   1999-09-11
#
#       rank  week
# 0     87.0     1
# 1     91.0     1
# ...

# %%
df['date'] = pd.to_datetime(df['date.entered'])
df = df.drop(columns='date.entered')

# %%
import numpy as np

x = (((df['week']) - 1) * 7)
df['date'] = df['date'] + pd.to_timedelta(np.ceil(x), unit="D")

df
# Out:
#       index  year        artist                    track  time  rank  week  \
# 0         0  2000         2 Pac  Baby Don't Cry (Keep...  4:22  87.0     1
# 1         1  2000       2Ge+her  The Hardest Part Of ...  3:15  91.0     1
# 2         2  2000  3 Doors Down               Kryptonite  3:53  81.0     1
# 3         3  2000  3 Doors Down                    Loser  4:24  76.0     1
# 4         4  2000      504 Boyz            Wobble Wobble  3:35  57.0     1
# ...     ...   ...           ...                      ...   ...   ...   ...
# 5302  19716  2000         Creed                   Higher  5:16  50.0    63
# 5303  19833  2000      Lonestar                   Amazed  4:25  45.0    63
# 5304  20033  2000         Creed                   Higher  5:16  50.0    64
# 5305  20150  2000      Lonestar                   Amazed  4:25  50.0    64
# 5306  20350  2000         Creed                   Higher  5:16  49.0    65
#
#            date
# 0    2000-02-26
# 1    2000-09-02
# ...

# %%
df = df.sort_values(by=['artist','date'])
df = df.reset_index()
df = df.rename(columns={'level_0': 'id'})
del df['index']
df = df.assign(id=(df['track']).astype('category').cat.codes)
df = df[['id','year','artist','track','time','date','week','rank']]

# %%
df_s = df.copy()
del df_s['year']
del df_s['date']
del df_s['week']
del df_s['rank']
df_s.drop_duplicates(inplace=True)

# %%
df_d = df.copy()
del df_d['year']
del df_d['artist']
del df_d['track']
del df_d['time']
del df_d['week']

# %%
df
# Out:
#       id  year           artist                    track  time       date  \
# 0     18  2000            2 Pac  Baby Don't Cry (Keep...  4:22 2000-02-26
# 1     18  2000            2 Pac  Baby Don't Cry (Keep...  4:22 2000-03-04
# 2     18  2000            2 Pac  Baby Don't Cry (Keep...  4:22 2000-03-11
# 3     18  2000            2 Pac  Baby Don't Cry (Keep...  4:22 2000-03-18
# 4     18  2000            2 Pac  Baby Don't Cry (Keep...  4:22 2000-03-25
# ...   ..   ...              ...                      ...   ...        ...
# 5302  27  2000  matchbox twenty                     Bent  4:12 2000-12-23
# 5303  27  2000  matchbox twenty                     Bent  4:12 2000-12-30
# 5304  27  2000  matchbox twenty                     Bent  4:12 2001-01-06
# 5305  27  2000  matchbox twenty                     Bent  4:12 2001-01-13
# 5306  27  2000  matchbox twenty                     Bent  4:12 2001-01-20
#
#       week  rank
# 0        1  87.0
# 1        2  82.0
# 2        3  72.0
# ...

# %%
df_s
# Out:
#        id            artist                    track  time
# 0      18             2 Pac  Baby Don't Cry (Keep...  4:22
# 7     258           2Ge+her  The Hardest Part Of ...  3:15
# 10    150      3 Doors Down               Kryptonite  3:53
# 38    161      3 Doors Down                    Loser  4:24
# 83    304          504 Boyz            Wobble Wobble  3:35
# ...   ...               ...                      ...   ...
# 5238   14       Yankee Grey     Another Nine Minutes  3:10
# 5246  208  Yearwood, Trisha          Real Live Woman  3:55
# 5252  298   Ying Yang Twins  Whistle While You Tw...  4:19
# 5266  148     Zombie Nation            Kernkraft 400  3:30
# 5268   27   matchbox twenty                     Bent  4:12
#
# [317 rows x 4 columns]

# %%
df_d
# Out:
#       id       date  rank
# 0     18 2000-02-26  87.0
# 1     18 2000-03-04  82.0
# 2     18 2000-03-11  72.0
# 3     18 2000-03-18  77.0
# 4     18 2000-03-25  87.0
# ...   ..        ...   ...
# 5302  27 2000-12-23  33.0
# 5303  27 2000-12-30  37.0
# 5304  27 2001-01-06  38.0
# 5305  27 2001-01-13  38.0
# 5306  27 2001-01-20  48.0
#
# [5307 rows x 3 columns]

# %%
#sh_z
