# %%
import pandas as pd

df =pd.read_csv('./assignments/pew.csv')
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
df = df.melt(id_vars='religion', var_name='income', value_name='freq')
df.to_excel(r'pew_data_.xlsx')

# %%
df
# Out:
#                   religion  income   freq
# 0                 Agnostic  income  <$10k
# 1                  Atheist  income  <$10k
# 2                 Buddhist  income  <$10k
# 3                 Catholic  income  <$10k
# 4       Don’t know/refused  income  <$10k
# ..                     ...     ...    ...
# 355               Orthodox   count     73
# 356        Other Christian   count     18
# 357           Other Faiths   count     71
# 358  Other World Religions   count      8
# 359           Unaffiliated   count    597
#
# [360 rows x 3 columns]

# %%
df.tail(50)
# Out:
#                     religion income  freq
# 310       Don’t know/refused  count    17
# 311         Evangelical Prot  count   723
# 312                    Hindu  count    48
# 313  Historically Black Prot  count    81
# 314        Jehovah's Witness  count    11
# 315                   Jewish  count    87
# 316            Mainline Prot  count   753
# 317                   Mormon  count    49
# 318                   Muslim  count     8
# 319                 Orthodox  count    42
# 320          Other Christian  count    14
# 321             Other Faiths  count    40
# 322    Other World Religions  count     4
# 323             Unaffiliated  count   321
# 324                 Agnostic  count    84
# 325                  Atheist  count    74
# 326                 Buddhist  count    53
# 327                 Catholic  count   633
# 328       Don’t know/refused  count    18
# 329         Evangelical Prot  count   414
# 330                    Hindu  count    54
# ...
