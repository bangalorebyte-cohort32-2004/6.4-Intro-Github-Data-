# %%
import pandas as pd
import numpy as np
import re

# %%
df=pd.read_csv('country_timeseries.csv')
type(df)
df
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df_new=pd.melt(df,id_vars=['Date','Day'], var_name='Country', value_name='Count')

# %%
df_new.head(50)
# Out:
#           Date  Day       Country   Count
# 0     1/5/2015  289  Cases_Guinea  2776.0
# 1     1/4/2015  288  Cases_Guinea  2775.0
# 2     1/3/2015  287  Cases_Guinea  2769.0
# 3     1/2/2015  286  Cases_Guinea     NaN
# 4   12/31/2014  284  Cases_Guinea  2730.0
# 5   12/28/2014  281  Cases_Guinea  2706.0
# 6   12/27/2014  280  Cases_Guinea  2695.0
# 7   12/24/2014  277  Cases_Guinea  2630.0
# 8   12/21/2014  273  Cases_Guinea  2597.0
# 9   12/20/2014  272  Cases_Guinea  2571.0
# 10  12/18/2014  271  Cases_Guinea     NaN
# 11  12/14/2014  267  Cases_Guinea  2416.0
# 12   12/9/2014  262  Cases_Guinea     NaN
# 13   12/7/2014  260  Cases_Guinea  2292.0
# 14   12/3/2014  256  Cases_Guinea     NaN
# 15  11/30/2014  253  Cases_Guinea  2164.0
# 16  11/28/2014  251  Cases_Guinea     NaN
# 17  11/23/2014  246  Cases_Guinea  2134.0
# 18  11/22/2014  245  Cases_Guinea     NaN
# 19  11/18/2014  241  Cases_Guinea  2047.0
# 20  11/16/2014  239  Cases_Guinea  1971.0
# ...

# %%
# df_dict=df.to_dict
# df_dict

# %%
df_new_edit=df_new
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new_edit[['#of','country']] = df_new_edit.Country.str.split("_",expand=True)

# %%
df_new_edit
# Out:
#             Date  Day       Country   Count     #of country
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases  Guinea
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases  Guinea
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases  Guinea
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases  Guinea
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases  Guinea
# ...          ...  ...           ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths    Mali
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths    Mali
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths    Mali
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths    Mali
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths    Mali
#
# [1952 rows x 6 columns]

# %%
# type(df_new_edit)
# Out:
# pandas.core.series.Series

# %%
df_1=pd.DataFrame(df_new_edit)

# %%
type(df_new_edit)
# Out:
# pandas.core.frame.DataFrame

# %%
df_2=df_1.drop(["Country"], axis=1)

# %%
df_2.head(50)
# Out:
#           Date  Day   Count    #of country
# 0     1/5/2015  289  2776.0  Cases  Guinea
# 1     1/4/2015  288  2775.0  Cases  Guinea
# 2     1/3/2015  287  2769.0  Cases  Guinea
# 3     1/2/2015  286     NaN  Cases  Guinea
# 4   12/31/2014  284  2730.0  Cases  Guinea
# 5   12/28/2014  281  2706.0  Cases  Guinea
# 6   12/27/2014  280  2695.0  Cases  Guinea
# 7   12/24/2014  277  2630.0  Cases  Guinea
# 8   12/21/2014  273  2597.0  Cases  Guinea
# 9   12/20/2014  272  2571.0  Cases  Guinea
# 10  12/18/2014  271     NaN  Cases  Guinea
# 11  12/14/2014  267  2416.0  Cases  Guinea
# 12   12/9/2014  262     NaN  Cases  Guinea
# 13   12/7/2014  260  2292.0  Cases  Guinea
# 14   12/3/2014  256     NaN  Cases  Guinea
# 15  11/30/2014  253  2164.0  Cases  Guinea
# 16  11/28/2014  251     NaN  Cases  Guinea
# 17  11/23/2014  246  2134.0  Cases  Guinea
# 18  11/22/2014  245     NaN  Cases  Guinea
# 19  11/18/2014  241  2047.0  Cases  Guinea
# 20  11/16/2014  239  1971.0  Cases  Guinea
# ...

# %%
df_2['Date']=pd.to_datetime(df_2['Date'])

# %%
df_2
# Out:
#            Date  Day   Count     #of country
# 0    2015-01-05  289  2776.0   Cases  Guinea
# 1    2015-01-04  288  2775.0   Cases  Guinea
# 2    2015-01-03  287  2769.0   Cases  Guinea
# 3    2015-01-02  286     NaN   Cases  Guinea
# 4    2014-12-31  284  2730.0   Cases  Guinea
# ...         ...  ...     ...     ...     ...
# 1947 2014-03-27    5     NaN  Deaths    Mali
# 1948 2014-03-26    4     NaN  Deaths    Mali
# 1949 2014-03-25    3     NaN  Deaths    Mali
# 1950 2014-03-24    2     NaN  Deaths    Mali
# 1951 2014-03-22    0     NaN  Deaths    Mali
#
# [1952 rows x 5 columns]

# %%
df_2.sort_values(by=['country','Day'], ascending='False')
df_2.head(50)
# Out:
#          Date  Day   Count    #of country
# 0  2015-01-05  289  2776.0  Cases  Guinea
# 1  2015-01-04  288  2775.0  Cases  Guinea
# 2  2015-01-03  287  2769.0  Cases  Guinea
# 3  2015-01-02  286     NaN  Cases  Guinea
# 4  2014-12-31  284  2730.0  Cases  Guinea
# 5  2014-12-28  281  2706.0  Cases  Guinea
# 6  2014-12-27  280  2695.0  Cases  Guinea
# 7  2014-12-24  277  2630.0  Cases  Guinea
# 8  2014-12-21  273  2597.0  Cases  Guinea
# 9  2014-12-20  272  2571.0  Cases  Guinea
# 10 2014-12-18  271     NaN  Cases  Guinea
# 11 2014-12-14  267  2416.0  Cases  Guinea
# 12 2014-12-09  262     NaN  Cases  Guinea
# 13 2014-12-07  260  2292.0  Cases  Guinea
# 14 2014-12-03  256     NaN  Cases  Guinea
# 15 2014-11-30  253  2164.0  Cases  Guinea
# 16 2014-11-28  251     NaN  Cases  Guinea
# 17 2014-11-23  246  2134.0  Cases  Guinea
# 18 2014-11-22  245     NaN  Cases  Guinea
# 19 2014-11-18  241  2047.0  Cases  Guinea
# 20 2014-11-16  239  1971.0  Cases  Guinea
# ...

# %%
table = df_2.pivot_table(df_2, index=['country','Date', 'Day'],columns=['#of'], aggfunc=np.sum)
table.head(50)
# Out:
#                         Count
# #of                     Cases Deaths
# country Date       Day
# Guinea  2014-03-22 0     49.0   29.0
#         2014-03-24 2     86.0   59.0
#         2014-03-25 3     86.0   60.0
#         2014-03-26 4     86.0   62.0
#         2014-03-27 5    103.0   66.0
#         2014-03-28 6    112.0   70.0
#         2014-03-29 7    112.0   70.0
#         2014-03-31 9    122.0   80.0
#         2014-04-01 10   127.0   83.0
#         2014-04-04 13   143.0   86.0
#         2014-04-07 16   151.0   95.0
#         2014-04-09 18   158.0  101.0
#         2014-04-11 20   159.0  106.0
#         2014-04-14 23   168.0  108.0
#         2014-04-15 24     0.0    0.0
#         2014-04-16 25   197.0  122.0
#         2014-04-17 26   203.0  129.0
#         2014-04-20 29   208.0  136.0
#         2014-04-21 30     0.0    0.0
#         2014-04-22 31     0.0    0.0
#         2014-04-23 32   218.0  141.0
#         2014-04-24 33     0.0    0.0
#         2014-04-26 35   224.0  143.0
# ...

# %%
table.sort_values(by=['country','Day'], ascending='True')
table.head(50)
# Out:
#                         Count
# #of                     Cases Deaths
# country Date       Day
# Guinea  2014-03-22 0     49.0   29.0
#         2014-03-24 2     86.0   59.0
#         2014-03-25 3     86.0   60.0
#         2014-03-26 4     86.0   62.0
#         2014-03-27 5    103.0   66.0
#         2014-03-28 6    112.0   70.0
#         2014-03-29 7    112.0   70.0
#         2014-03-31 9    122.0   80.0
#         2014-04-01 10   127.0   83.0
#         2014-04-04 13   143.0   86.0
#         2014-04-07 16   151.0   95.0
#         2014-04-09 18   158.0  101.0
#         2014-04-11 20   159.0  106.0
#         2014-04-14 23   168.0  108.0
#         2014-04-15 24     0.0    0.0
#         2014-04-16 25   197.0  122.0
#         2014-04-17 26   203.0  129.0
#         2014-04-20 29   208.0  136.0
#         2014-04-21 30     0.0    0.0
#         2014-04-22 31     0.0    0.0
#         2014-04-23 32   218.0  141.0
#         2014-04-24 33     0.0    0.0
#         2014-04-26 35   224.0  143.0
# ...
